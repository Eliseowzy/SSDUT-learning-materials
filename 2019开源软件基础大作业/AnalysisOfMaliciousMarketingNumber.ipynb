# %%
# author:  迟紫薇，董可欣，刘家瑜

# %%
import pandas as pd

# %% [markdown]
#  # 营销号读取

# %%
df = pd.read_csv('C:/Users/迟紫薇/Desktop/3314422837.csv')

# %%
df2 = pd.read_csv('C:/Users/迟紫薇/Desktop/2156045842.csv')

# %%
df3 = pd.read_csv('C:/Users/迟紫薇/Desktop/2438867634.csv')

# %%
df4 = pd.read_csv('C:/Users/迟紫薇/Desktop/6363445910.csv')

# %%
df
# Out:
#                    id        bid  \
# 0    4454116745156754  ImHP4lDvs
# 1    4454100143470613  ImHoieyRD
# 2    4454081604698984  ImGUojIq4
# 3    4454069797966690  ImGBlxqv0
# 4    4454066229093868  ImGvAC9Ji
# ..                ...        ...
# 483  4444679636485261  IiKjVrd6Z
# 484  4444646522927427  IiJswchyz
# 485  4444637080950508  IiJdi3ZgM
# 486  4444629674242251  IiJ1lhNBp
# 487  4444624069940598  IiISiFI0e
#
#                                                     正文  \
# 0    #首都一橘#赵磊超话 感谢@赵磊30M全球后援会 送来的生日应援[求關注]提前祝元旦宝宝赵磊...
# 1    #首都一橘#黄明昊超话 哈哈哈哈“活体ETC”可以随时随地抬杠不错，又学到了一个新词 首都一...
# 2                  #首都一橘# 快来接收甜酒果送给学生党的四行诗哥哥果然很了解阿米呢～
# 3                        #首都一橘#何昶希超话 当代年轻人现状一览（bushi）
# 4    #唐探网剧定档#了！2020元旦就可以看#网剧唐人街探案#也太幸福了吧！邱泽、张钧甯、王真儿...
# ..                                                 ...
# 483  #汪涵称想何炅了#涵哥在《野生厨房》隔空表白何炅了？哈哈哈原来是涵哥吃到了沾着姜妍制作的“汁...
# 484                  #首都一橘# 本质上还是很（可）MAN（爱）的小朋友何洛洛超话
# 485  #首都一橘##贝雷帽到底有多难戴# 果然少年和贝雷帽适配度很高，空气里都弥漫着一股甜味儿[給...
# ...

# %%
df['点评转'] = df.点赞数+df.评论数+df.转发数

# %%
df.sort_values(by=['点评转'],ascending=False).head(10)
# Out:
#                    id        bid  \
# 82   4452355833446727  IlY0TesEn
# 323  4447329199254171  IjRfpCPqP
# 416  4445866897349461  IjfcRuPVH
# 438  4445516026667551  Ij64WrYx9
# 306  4447638516157808  IjZijpPVu
# 252  4448737273753265  IkrSvfKox
# 426  4445748248542167  Ijc7uzQcT
# 268  4448432229615136  IkjWuElkQ
# 320  4447356806178440  IjRXWpVig
# 246  4448982493396511  Ikyg1efAr
#
#                                                     正文  \
# 82   #易烊千玺演唱会送粉丝礼物# 演唱会群访完整版  回应了昨晚的手机打字：“因为昨天晚上下雨了...
# 323  #首都一橘##腾讯音乐娱乐盛典# 今晚又是一场视听盛宴了，果然一到年末盛典首页就变得异常热闹...
# 416  #首都一橘##2019MAMA# MAMA看到现在发现有好多精彩舞台啊来跟说说今晚你最喜欢哪...
# 438  #搞到宝# 单纯毕雯珺 ，不断被套路爱豆去演戏不是因为没有办法才去，不怕被分析演技送礼物送镜...
# 306  #首都一橘# 来啦来啦，李现 辣访repo来啦！印象比较深的有两个1.当天他接了不少采访，知...
# 252  #首都一橘##湖南卫视跨年阵容# 今年的湖南卫视跨年是什么组合收割机啊？TFBOYS、TNT...
# 426                          #首都一橘# 这可能是我和李佳琦唯一的相似之处了
# 268  #首都一橘##男团到底有多吵# 总有那么一群人，只要聚在一起，输出全靠吼来，快把那群让你们疯...
# 320  #王俊凯两次拿奖杯的样子# #王俊凯灯不亮#  天呢被王俊凯一段rap给蛊了舞台粉真的太爽了...
# ...

# %%
df2
# Out:
#                   id        bid  \
# 0   4453883017065777  ImBK5tE89
# 1   4453860993096952  ImBazcZEQ
# 2   4453856958278492  ImB43yJC4
# 3   4453794177377174  ImzqNuX8G
# 4   4453786887758748  Imzf2wyp6
# ..               ...        ...
# 75  4445114136935360  IiVCJt6cE
# 76  4445103416342385  IiVlrqBWx
# 77  4444831445407679  IiOgMmGMD
# 78  4444763090217443  IiMux0Uz9
# 79  4444736896993726  IiLOhtlo2
#
#                                                    正文  \
# 0   #张若昀剧透庆余年剧情# 张若昀说要给李佳琦剧透庆余年剧情，然后开始一本正经地胡说八道……庆...
# 1   #林更新不介意女友穿热裤# 林更新说对于自己的另一半，就算有自私的想法，也会因为爱她而愿意支...
# 2   #该不该干涉伴侣穿着#其实这道辩题背后的意义不是该不该阻止伴侣穿热裤，而是能不能与女性站在同...
# 3   顶着少年的颜，操着老父亲的心，这语重心长的样子莫名很可爱了  #综艺评论局#  吃瓜少女芒果...
# 4   #你被怼high过吗# 现在的素人越来越难带了 金星李诞张绍刚在#出发吧师傅# 被一位重庆师...
# ..                                                ...
# 75  #云养儿的快乐你想象不到#建厚小猪猪化身圣诞老人跳舞,可爱暴击啊!!!!!!还有最后那句re...
# 76  害，北方都下雪了而你还，知道对象来不了，#明天拼车好不好#？拼成1折，对你自己好一点。#12...
# 77                    嚯嚯嚯！本少女的高光时刻#奇葩说# 现场观战果然更刺激！！！
# ...

# %%
df3
# Out:
#                   id        bid  \
# 0   4454085102838559  ImH02bUrd
# 1   4454080321660739  ImGSk6Y27
# 2   4454069038858070  ImGA7Bao6
# 3   4454037279648297  ImFKTEtXH
# 4   4453803891699911  ImzGt78dV
# ..               ...        ...
# 62  4445696642049359  IjaMg8B8b
# 63  4445451606803557  Ij4p2sxUN
# 64  4445343553402541  Ij1ALeh9H
# 65  4445097703295617  IiVcedPl7
# 66  4444630827318387  IiJ3cuHQv
#
#                                                    正文  \
# 0   #如果你的零食是二次元人物# 可盐可甜可辣！如果有一天零食真的成了动漫人物，我最爱的一定是猪...
# 1                                  每人分享一张最近新保存的表情包吧。
# 2                                          「跟我一起撑伞吧」
# 3   女孩们一生中可能会面对许多忧虑，害怕跑得不及同龄人快，担心没对象，但遇见了她，所有恐惧都会被...
# 4                                 每人分享一张最近新保存的表情包吧！！
# ..                                                ...
# 62                                           好巧哦，我也是
# 63                                         【杂图小表情合集】
# 64                                        每个工作日都是如此：
# ...

# %%
df4
# Out:
#                    id        bid  \
# 0    4454117948530217  ImHR0zN69
# 1    4454114219863566  ImHKZFnXM
# 2    4454106531833368  ImHyB7GWs
# 3    4454103046488268  ImHsYrdTu
# 4    4454099561277157  ImHnm5mfj
# ..                ...        ...
# 938  4444652469679255  IiJC6EC11
# 939  4444647549860425  IiJuaFn97
# 940  4444641967175088  IiJlau6ze
# 941  4444637307558174  IiJdEvIe2
# 942  4444631679288753  IiJ4zCYqB
#
#                                                     正文  \
# 0    王俊凯又拿下了一本开年封《睿士ELLEMEN》的一月刊，这一次主打的是粉末大片，您觉得拍的怎...
# 1    王嘉尔登上了全球十大时尚杂志之一的《Flaunt》，成为国内首位登封的男艺人，王嘉尔这表现力...
# 2    男星短裤造型来了，陈飞宇、张艺兴、朱正廷、吴磊、胡一天、王俊凯、刘昊然、范丞丞，大家觉得谁更好看
# 3            吴亦凡和鹿晗转发了黄子韬的新歌，黄子韬ins表白吴亦凡鹿晗，时间过得真快都8年了
# 4                            组里爆料星光大赏奖项图，来康康这些都是实至名归吗
# ..                                                 ...
# 938  肖战和王一博的CP粉博君一肖，居然在故宫墙上，用雪写了博君一肖是真的缩写“bjyxszd”，...
# 939            来看看孟美岐的古风反串造型，底下评论说英姿飒爽，有些许帅气，您觉得怎么样呢？
# 940  肖战的数据站居然转发了，陈立农上快乐大本营的表演视频，随后出来澄清说是微博卡顿导致，这操作你...
# ...

# %%
df.loc[df['正文'].str.contains('Lisa') & (df['正文'].str.contains('蔡徐坤'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户, 点评转]
# Index: []

# %%
df2.loc[df2['正文'].str.contains('Lisa') & (df2['正文'].str.contains('蔡徐坤'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df3.loc[df3['正文'].str.contains('Lisa') & (df3['正文'].str.contains('蔡徐坤'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df4.loc[df4['正文'].str.contains('Lisa') & (df4['正文'].str.contains('蔡徐坤'))]
# Out:
#                   id        bid                                     正文  \
# 54  4453699868783931  ImwYGAR6j  组里爆料称蔡徐坤和Lisa将有合作舞台，中韩顶流男女爱豆同台，你们期待吗
#
#                                               原始图片url  视频url          日期  \
# 54  https://wx3.sinaimg.cn/large/006WEmYmgy1ga9xh5...    NaN  2019-12-26
#
#      点赞数  评论数  转发数   话题  @用户
# 54  1554  356  121  NaN  NaN

# %%
df.loc[df['正文'].str.contains('焉栩嘉') & (df['正文'].str.contains('蔡徐坤'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户, 点评转]
# Index: []

# %%
df2.loc[df2['正文'].str.contains('焉栩嘉') & (df2['正文'].str.contains('蔡徐坤'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df3.loc[df3['正文'].str.contains('焉栩嘉') & (df3['正文'].str.contains('蔡徐坤'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df4.loc[df4['正文'].str.contains('焉栩嘉') & (df4['正文'].str.contains('蔡徐坤'))]
# Out:
#                   id        bid  \
# 35  4453798846048027  ImzykpnmP
#
#                                                    正文  \
# 35  焉栩嘉粉被蔡徐坤粉撕了，起因疑似是焉栩嘉后援会把蔡徐坤认证过的应援物“猫咪头箍”放到了自家应...
#
#                                               原始图片url  视频url          日期  \
# 35  https://wx3.sinaimg.cn/large/006WEmYmgy1gaa8tr...    NaN  2019-12-26
#
#      点赞数  评论数  转发数   话题  @用户
# 35  1539  216  106  NaN  NaN

# %%
df.loc[df['正文'].str.contains('李佳琦') & (df['正文'].str.contains('朱亚文'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户, 点评转]
# Index: []

# %%
df2.loc[df2['正文'].str.contains('李佳琦') & (df2['正文'].str.contains('朱亚文'))]
# Out:
#                  id        bid  \
# 7  4453500509269827  ImrN8CTvl
#
#                                                   正文 原始图片url  视频url  \
# 7  #朱亚文霸总式涂口红# ？？？这是什么霸总式的涂口红李佳琦：我大气都不敢喘 吃瓜少女芒果酱的...     NaN    NaN
#
#            日期    点赞数   评论数   转发数         话题  @用户
# 7  2019-12-25  11253  1254  2436  朱亚文霸总式涂口红  NaN

# %%
df3.loc[df3['正文'].str.contains('李佳琦') & (df3['正文'].str.contains('朱亚文'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df4.loc[df4['正文'].str.contains('李佳琦') & (df4['正文'].str.contains('朱亚文'))]
# Out:
#                   id        bid                                            正文  \
# 58  4453510986805327  Ims42synl  今天晚上李佳琦直播间朱亚文给李佳琦涂口红，这个涂口红的方式…网友说朱亚文真的是实力攻了
#
#                                               原始图片url  视频url          日期  \
# 58  https://wx3.sinaimg.cn/large/006WEmYmly1ga9brl...    NaN  2019-12-25
#
#      点赞数  评论数  转发数   话题  @用户
# 58  1301  264  147  NaN  NaN

# %%
df.loc[df['正文'].str.contains('杨幂') & (df['正文'].str.contains('金扫帚'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户, 点评转]
# Index: []

# %%
df2.loc[df2['正文'].str.contains('杨幂') & (df2['正文'].str.contains('金扫帚'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df3.loc[df['正文'].str.contains('杨幂') & (df3['正文'].str.contains('金扫帚'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df4.loc[df['正文'].str.contains('杨幂') & (df4['正文'].str.contains('金扫帚'))]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户]
# Index: []

# %%
df.loc[df['正文'].str.contains('2019-12')]
# Out:
# Empty DataFrame
# Columns: [id, bid, 正文, 原始图片url, 视频url, 日期, 点赞数, 评论数, 转发数, 话题, @用户, 点评转]
# Index: []
